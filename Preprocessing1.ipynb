# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Del22 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\AnandViharDelhi2022.csv", index_col="Timestamp", parse_dates=True)
Del23 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\AnandViharDelhi2023.csv", index_col="Timestamp", parse_dates=True)
Del24 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\AnandViharDelhi2024.csv", index_col="Timestamp", parse_dates=True)

# %%
delhi = pd.concat([Del22, Del23, Del24])
delhi
# Out:
#             PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# Timestamp
# 2022-01-01         393.56        598.82      214.12        99.19     222.79
# 2022-01-02         424.81        598.95      228.46        96.99     258.12
# 2022-01-03         375.52        636.12      199.10       109.72     237.60
# 2022-01-04         291.86        564.58      227.86        96.62     247.82
# 2022-01-05         353.05        449.37      118.76        60.40     128.94
# ...                   ...           ...         ...          ...        ...
# 2024-12-27         201.56        240.34       56.41        93.86      95.78
# 2024-12-28         111.92        151.11       93.26        97.74     127.79
# 2024-12-29         123.29        178.12       57.66        75.84      87.24
# 2024-12-30         106.01        181.87       49.98        67.24      76.41
# 2024-12-31         236.47        380.20       68.07        70.94      93.08
#
# ...

# %%
delhi.shape
# Out:
# (1096, 24)

# %%
delhi.size
# Out:
# 26304

# %%
delhi.columns
# Out:
# Index(['PM2.5 (µg/m³)', 'PM10 (µg/m³)', 'NO (µg/m³)', 'NO2 (µg/m³)',
#        'NOx (ppb)', 'NH3 (µg/m³)', 'SO2 (µg/m³)', 'CO (mg/m³)',
#        'Ozone (µg/m³)', 'Benzene (µg/m³)', 'Toluene (µg/m³)', 'Xylene (µg/m³)',
#        'O Xylene (µg/m³)', 'Eth-Benzene (µg/m³)', 'MP-Xylene (µg/m³)',
#        'AT (°C)', 'RH (%)', 'WS (m/s)', 'WD (deg)', 'RF (mm)', 'TOT-RF (mm)',
#        'SR (W/mt2)', 'BP (mmHg)', 'VWS (m/s)'],
#       dtype='str')

# %%
delhi.index.duplicated().sum()
# Out:
# np.int64(0)

# %%
delhi.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1096 entries, 2022-01-01 to 2024-12-31
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PM2.5 (µg/m³)        1064 non-null   float64
#  1   PM10 (µg/m³)         1059 non-null   float64
#  2   NO (µg/m³)           1050 non-null   float64
#  3   NO2 (µg/m³)          1050 non-null   float64
#  4   NOx (ppb)            1055 non-null   float64
#  5   NH3 (µg/m³)          1055 non-null   float64
#  6   SO2 (µg/m³)          1050 non-null   float64
#  7   CO (mg/m³)           1026 non-null   float64
#  8   Ozone (µg/m³)        1058 non-null   float64
#  9   Benzene (µg/m³)      874 non-null    float64
#  10  Toluene (µg/m³)      872 non-null    float64
#  11  Xylene (µg/m³)       0 non-null      float64
#  12  O Xylene (µg/m³)     0 non-null      float64
#  13  Eth-Benzene (µg/m³)  0 non-null      float64
#  14  MP-Xylene (µg/m³)    0 non-null      float64
# ...

# %%
delhi= delhi.sort_index()
delhi
# Out:
#             PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# Timestamp
# 2022-01-01         393.56        598.82      214.12        99.19     222.79
# 2022-01-02         424.81        598.95      228.46        96.99     258.12
# 2022-01-03         375.52        636.12      199.10       109.72     237.60
# 2022-01-04         291.86        564.58      227.86        96.62     247.82
# 2022-01-05         353.05        449.37      118.76        60.40     128.94
# ...                   ...           ...         ...          ...        ...
# 2024-12-27         201.56        240.34       56.41        93.86      95.78
# 2024-12-28         111.92        151.11       93.26        97.74     127.79
# 2024-12-29         123.29        178.12       57.66        75.84      87.24
# 2024-12-30         106.01        181.87       49.98        67.24      76.41
# 2024-12-31         236.47        380.20       68.07        70.94      93.08
#
# ...

# %%
delhi.to_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\Delhi_combined.csv", index=True)

# %%
delhi.isnull().sum()
# Out:
# PM2.5 (µg/m³)            32
# PM10 (µg/m³)             37
# NO (µg/m³)               46
# NO2 (µg/m³)              46
# NOx (ppb)                41
# NH3 (µg/m³)              41
# SO2 (µg/m³)              46
# CO (mg/m³)               70
# Ozone (µg/m³)            38
# Benzene (µg/m³)         222
# Toluene (µg/m³)         224
# Xylene (µg/m³)         1096
# O Xylene (µg/m³)       1096
# Eth-Benzene (µg/m³)    1096
# MP-Xylene (µg/m³)      1096
# AT (°C)                  33
# RH (%)                   33
# WS (m/s)                 42
# WD (deg)                 33
# RF (mm)                1096
# TOT-RF (mm)               0
# SR (W/mt2)               30
# BP (mmHg)               167
# VWS (m/s)              1096
# dtype: int64

# %%
(delhi.isnull().sum() / len(delhi)) * 100
# Out:
# PM2.5 (µg/m³)            2.919708
# PM10 (µg/m³)             3.375912
# NO (µg/m³)               4.197080
# NO2 (µg/m³)              4.197080
# NOx (ppb)                3.740876
# NH3 (µg/m³)              3.740876
# SO2 (µg/m³)              4.197080
# CO (mg/m³)               6.386861
# Ozone (µg/m³)            3.467153
# Benzene (µg/m³)         20.255474
# Toluene (µg/m³)         20.437956
# Xylene (µg/m³)         100.000000
# O Xylene (µg/m³)       100.000000
# Eth-Benzene (µg/m³)    100.000000
# MP-Xylene (µg/m³)      100.000000
# AT (°C)                  3.010949
# RH (%)                   3.010949
# WS (m/s)                 3.832117
# WD (deg)                 3.010949
# RF (mm)                100.000000
# TOT-RF (mm)              0.000000
# SR (W/mt2)               2.737226
# BP (mmHg)               15.237226
# VWS (m/s)              100.000000
# dtype: float64

# %%
delhi.columns = delhi.columns.str.split(" ").str[0]
delhi.isnull().sum()
# Out:
# PM2.5            32
# PM10             37
# NO               46
# NO2              46
# NOx              41
# NH3              41
# SO2              46
# CO               70
# Ozone            38
# Benzene         222
# Toluene         224
# Xylene         1096
# O              1096
# Eth-Benzene    1096
# MP-Xylene      1096
# AT               33
# RH               33
# WS               42
# WD               33
# RF             1096
# TOT-RF            0
# SR               30
# BP              167
# VWS            1096
# dtype: int64

# %%
delhi= delhi.ffill()
delhi= delhi.bfill()

# %%
delhi.isnull().sum()
# Out:
# PM2.5             0
# PM10              0
# NO                0
# NO2               0
# NOx               0
# NH3               0
# SO2               0
# CO                0
# Ozone             0
# Benzene           0
# Toluene           0
# Xylene         1096
# O              1096
# Eth-Benzene    1096
# MP-Xylene      1096
# AT                0
# RH                0
# WS                0
# WD                0
# RF             1096
# TOT-RF            0
# SR                0
# BP                0
# VWS            1096
# dtype: int64

# %%
delhi.to_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\Delhi_combined_refined.csv", index=True)

# %%
Mumb22 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\ColabaMumbai2022.csv", index_col="Timestamp", parse_dates=True)
Mumb23 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\ColabaMumbai2023.csv", index_col="Timestamp", parse_dates=True)
Mumb24 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\ColabaMumbai2024.csv", index_col="Timestamp", parse_dates=True)

# %%
mumbai = pd.concat([Mumb22, Mumb23, Mumb24])
mumbai
# Out:
#             PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# Timestamp
# 2022-01-01          52.26        111.27        0.92         8.50       9.42
# 2022-01-02          56.66        120.21        4.81         9.35      14.16
# 2022-01-03          61.15        123.23        5.12         9.06      14.18
# 2022-01-04          86.90        154.63        6.33        12.13      18.46
# 2022-01-05          74.61        151.99        5.00         9.69      14.69
# ...                   ...           ...         ...          ...        ...
# 2024-12-27          59.28         93.41       12.39        20.31      32.70
# 2024-12-28          82.26        112.49       12.58        20.64      33.22
# 2024-12-29          74.69        101.41       12.98        21.29      34.27
# 2024-12-30          46.77         71.90       11.69        19.18      30.87
# 2024-12-31          51.95         78.63       12.30        20.18      32.48
#
# ...

# %%
mumbai.shape
# Out:
# (1096, 24)

# %%
mumbai.size
# Out:
# 26304

# %%
mumbai.columns
# Out:
# Index(['PM2.5 (µg/m³)', 'PM10 (µg/m³)', 'NO (µg/m³)', 'NO2 (µg/m³)',
#        'NOx (ppb)', 'NH3 (µg/m³)', 'SO2 (µg/m³)', 'CO (mg/m³)',
#        'Ozone (µg/m³)', 'Benzene (µg/m³)', 'Toluene (µg/m³)', 'Xylene (µg/m³)',
#        'O Xylene (µg/m³)', 'Eth-Benzene (µg/m³)', 'MP-Xylene (µg/m³)',
#        'AT (°C)', 'RH (%)', 'WS (m/s)', 'WD (deg)', 'RF (mm)', 'TOT-RF (mm)',
#        'SR (W/mt2)', 'BP (mmHg)', 'VWS (m/s)'],
#       dtype='str')

# %%
mumbai.index.duplicated().sum()
# Out:
# np.int64(0)

# %%
mumbai.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1096 entries, 2022-01-01 to 2024-12-31
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PM2.5 (µg/m³)        967 non-null    float64
#  1   PM10 (µg/m³)         1039 non-null   float64
#  2   NO (µg/m³)           954 non-null    float64
#  3   NO2 (µg/m³)          931 non-null    float64
#  4   NOx (ppb)            998 non-null    float64
#  5   NH3 (µg/m³)          995 non-null    float64
#  6   SO2 (µg/m³)          987 non-null    float64
#  7   CO (mg/m³)           1044 non-null   float64
#  8   Ozone (µg/m³)        1045 non-null   float64
#  9   Benzene (µg/m³)      1043 non-null   float64
#  10  Toluene (µg/m³)      0 non-null      float64
#  11  Xylene (µg/m³)       0 non-null      float64
#  12  O Xylene (µg/m³)     0 non-null      float64
#  13  Eth-Benzene (µg/m³)  636 non-null    float64
#  14  MP-Xylene (µg/m³)    636 non-null    float64
# ...

# %%
mumbai= mumbai.sort_index()
mumbai
# Out:
#             PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# Timestamp
# 2022-01-01          52.26        111.27        0.92         8.50       9.42
# 2022-01-02          56.66        120.21        4.81         9.35      14.16
# 2022-01-03          61.15        123.23        5.12         9.06      14.18
# 2022-01-04          86.90        154.63        6.33        12.13      18.46
# 2022-01-05          74.61        151.99        5.00         9.69      14.69
# ...                   ...           ...         ...          ...        ...
# 2024-12-27          59.28         93.41       12.39        20.31      32.70
# 2024-12-28          82.26        112.49       12.58        20.64      33.22
# 2024-12-29          74.69        101.41       12.98        21.29      34.27
# 2024-12-30          46.77         71.90       11.69        19.18      30.87
# 2024-12-31          51.95         78.63       12.30        20.18      32.48
#
# ...

# %%
mumbai.to_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\Mumbai_combined.csv", index=True)

# %%
mumbai.isnull().sum()
# Out:
# PM2.5 (µg/m³)           129
# PM10 (µg/m³)             57
# NO (µg/m³)              142
# NO2 (µg/m³)             165
# NOx (ppb)                98
# NH3 (µg/m³)             101
# SO2 (µg/m³)             109
# CO (mg/m³)               52
# Ozone (µg/m³)            51
# Benzene (µg/m³)          53
# Toluene (µg/m³)        1096
# Xylene (µg/m³)         1096
# O Xylene (µg/m³)       1096
# Eth-Benzene (µg/m³)     460
# MP-Xylene (µg/m³)       460
# AT (°C)                  67
# RH (%)                   54
# WS (m/s)                 53
# WD (deg)                 53
# RF (mm)                1096
# TOT-RF (mm)               0
# SR (W/mt2)              918
# BP (mmHg)               247
# VWS (m/s)              1096
# dtype: int64

# %%
(mumbai.isnull().sum()/len(mumbai))*100
# Out:
# PM2.5 (µg/m³)           11.770073
# PM10 (µg/m³)             5.200730
# NO (µg/m³)              12.956204
# NO2 (µg/m³)             15.054745
# NOx (ppb)                8.941606
# NH3 (µg/m³)              9.215328
# SO2 (µg/m³)              9.945255
# CO (mg/m³)               4.744526
# Ozone (µg/m³)            4.653285
# Benzene (µg/m³)          4.835766
# Toluene (µg/m³)        100.000000
# Xylene (µg/m³)         100.000000
# O Xylene (µg/m³)       100.000000
# Eth-Benzene (µg/m³)     41.970803
# MP-Xylene (µg/m³)       41.970803
# AT (°C)                  6.113139
# RH (%)                   4.927007
# WS (m/s)                 4.835766
# WD (deg)                 4.835766
# RF (mm)                100.000000
# TOT-RF (mm)              0.000000
# SR (W/mt2)              83.759124
# BP (mmHg)               22.536496
# VWS (m/s)              100.000000
# dtype: float64

# %%
mumbai.columns = mumbai.columns.str.split(" ").str[0]
mumbai.isnull().sum()
# Out:
# PM2.5           129
# PM10             57
# NO              142
# NO2             165
# NOx              98
# NH3             101
# SO2             109
# CO               52
# Ozone            51
# Benzene          53
# Toluene        1096
# Xylene         1096
# O              1096
# Eth-Benzene     460
# MP-Xylene       460
# AT               67
# RH               54
# WS               53
# WD               53
# RF             1096
# TOT-RF            0
# SR              918
# BP              247
# VWS            1096
# dtype: int64

# %%
mumbai= mumbai.ffill()
mumbai= mumbai.bfill()

# %%
mumbai.isnull().sum()
# Out:
# PM2.5             0
# PM10              0
# NO                0
# NO2               0
# NOx               0
# NH3               0
# SO2               0
# CO                0
# Ozone             0
# Benzene           0
# Toluene        1096
# Xylene         1096
# O              1096
# Eth-Benzene       0
# MP-Xylene         0
# AT                0
# RH                0
# WS                0
# WD                0
# RF             1096
# TOT-RF            0
# SR                0
# BP                0
# VWS            1096
# dtype: int64

# %%
mumbai.to_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\Mumbai_combined_refined.csv", index=True)

# %%
Kolkt22 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\RabindraBharatiKolkata2022.csv", index_col="Timestamp", parse_dates=True)
Kolkt23 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\RabindraBharatiKolkata2023.csv", index_col="Timestamp", parse_dates=True)
Kolkt24 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\RabindraBharatiKolkata2024.csv", index_col="Timestamp", parse_dates=True)

# %%
kolkata= pd.concat([Kolkt22, Kolkt23, Kolkt24])
kolkata
# Out:
#             PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# Timestamp
# 2022-01-01         113.29        190.47        9.32        26.51      35.83
# 2022-01-02         121.76        201.37       10.02        26.41      36.39
# 2022-01-03         129.84        224.62       12.66        29.13      41.79
# 2022-01-04         170.97        258.60        8.44        27.49      35.94
# 2022-01-05         182.03        277.74        9.88        28.17      38.13
# ...                   ...           ...         ...          ...        ...
# 2024-12-27          57.02        148.71       17.09        28.55      42.92
# 2024-12-28          67.65        164.72       25.93        38.04      61.26
# 2024-12-29          74.64        186.42       26.76        40.60      64.65
# 2024-12-30          78.44        155.79       15.05        28.51      40.84
# 2024-12-31          72.62        132.30       10.43        21.16      28.88
#
# ...

# %%
kolkata.shape
# Out:
# (1096, 24)

# %%
kolkata.size
# Out:
# 26304

# %%
kolkata.columns
# Out:
# Index(['PM2.5 (µg/m³)', 'PM10 (µg/m³)', 'NO (µg/m³)', 'NO2 (µg/m³)',
#        'NOx (ppb)', 'NH3 (µg/m³)', 'SO2 (µg/m³)', 'CO (mg/m³)',
#        'Ozone (µg/m³)', 'Benzene (µg/m³)', 'Toluene (µg/m³)', 'Xylene (µg/m³)',
#        'O Xylene (µg/m³)', 'Eth-Benzene (µg/m³)', 'MP-Xylene (µg/m³)',
#        'AT (°C)', 'RH (%)', 'WS (m/s)', 'WD (deg)', 'RF (mm)', 'TOT-RF (mm)',
#        'SR (W/mt2)', 'BP (mmHg)', 'VWS (m/s)'],
#       dtype='str')

# %%
kolkata.index.duplicated().sum()
# Out:
# np.int64(0)

# %%
kolkata.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1096 entries, 2022-01-01 to 2024-12-31
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PM2.5 (µg/m³)        1081 non-null   float64
#  1   PM10 (µg/m³)         1081 non-null   float64
#  2   NO (µg/m³)           1061 non-null   float64
#  3   NO2 (µg/m³)          1060 non-null   float64
#  4   NOx (ppb)            1062 non-null   float64
#  5   NH3 (µg/m³)          1060 non-null   float64
#  6   SO2 (µg/m³)          1080 non-null   float64
#  7   CO (mg/m³)           1079 non-null   float64
#  8   Ozone (µg/m³)        1078 non-null   float64
#  9   Benzene (µg/m³)      1081 non-null   float64
#  10  Toluene (µg/m³)      1081 non-null   float64
#  11  Xylene (µg/m³)       0 non-null      float64
#  12  O Xylene (µg/m³)     0 non-null      float64
#  13  Eth-Benzene (µg/m³)  843 non-null    float64
#  14  MP-Xylene (µg/m³)    1081 non-null   float64
# ...

# %%
kolkata= kolkata.sort_index()
kolkata
# Out:
#             PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# Timestamp
# 2022-01-01         113.29        190.47        9.32        26.51      35.83
# 2022-01-02         121.76        201.37       10.02        26.41      36.39
# 2022-01-03         129.84        224.62       12.66        29.13      41.79
# 2022-01-04         170.97        258.60        8.44        27.49      35.94
# 2022-01-05         182.03        277.74        9.88        28.17      38.13
# ...                   ...           ...         ...          ...        ...
# 2024-12-27          57.02        148.71       17.09        28.55      42.92
# 2024-12-28          67.65        164.72       25.93        38.04      61.26
# 2024-12-29          74.64        186.42       26.76        40.60      64.65
# 2024-12-30          78.44        155.79       15.05        28.51      40.84
# 2024-12-31          72.62        132.30       10.43        21.16      28.88
#
# ...

# %%
kolkata.to_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\Kolkata_combined.csv", index=True)

# %%
kolkata.isnull().sum()
# Out:
# PM2.5 (µg/m³)            15
# PM10 (µg/m³)             15
# NO (µg/m³)               35
# NO2 (µg/m³)              36
# NOx (ppb)                34
# NH3 (µg/m³)              36
# SO2 (µg/m³)              16
# CO (mg/m³)               17
# Ozone (µg/m³)            18
# Benzene (µg/m³)          15
# Toluene (µg/m³)          15
# Xylene (µg/m³)         1096
# O Xylene (µg/m³)       1096
# Eth-Benzene (µg/m³)     253
# MP-Xylene (µg/m³)        15
# AT (°C)                 253
# RH (%)                   15
# WS (m/s)                 15
# WD (deg)                 15
# RF (mm)                 253
# TOT-RF (mm)               0
# SR (W/mt2)               16
# BP (mmHg)                99
# VWS (m/s)                16
# dtype: int64

# %%
(kolkata.isnull().sum()/len(kolkata))*100
# Out:
# PM2.5 (µg/m³)            1.368613
# PM10 (µg/m³)             1.368613
# NO (µg/m³)               3.193431
# NO2 (µg/m³)              3.284672
# NOx (ppb)                3.102190
# NH3 (µg/m³)              3.284672
# SO2 (µg/m³)              1.459854
# CO (mg/m³)               1.551095
# Ozone (µg/m³)            1.642336
# Benzene (µg/m³)          1.368613
# Toluene (µg/m³)          1.368613
# Xylene (µg/m³)         100.000000
# O Xylene (µg/m³)       100.000000
# Eth-Benzene (µg/m³)     23.083942
# MP-Xylene (µg/m³)        1.368613
# AT (°C)                 23.083942
# RH (%)                   1.368613
# WS (m/s)                 1.368613
# WD (deg)                 1.368613
# RF (mm)                 23.083942
# TOT-RF (mm)              0.000000
# SR (W/mt2)               1.459854
# BP (mmHg)                9.032847
# VWS (m/s)                1.459854
# dtype: float64

# %%
kolkata.columns = kolkata.columns.str.split(" ").str[0]
kolkata.isnull().sum()
# Out:
# PM2.5            15
# PM10             15
# NO               35
# NO2              36
# NOx              34
# NH3              36
# SO2              16
# CO               17
# Ozone            18
# Benzene          15
# Toluene          15
# Xylene         1096
# O              1096
# Eth-Benzene     253
# MP-Xylene        15
# AT              253
# RH               15
# WS               15
# WD               15
# RF              253
# TOT-RF            0
# SR               16
# BP               99
# VWS              16
# dtype: int64

# %%
kolkata= kolkata.ffill()
kolkata= kolkata.bfill()

# %%
kolkata.isnull().sum()
# Out:
# PM2.5             0
# PM10              0
# NO                0
# NO2               0
# NOx               0
# NH3               0
# SO2               0
# CO                0
# Ozone             0
# Benzene           0
# Toluene           0
# Xylene         1096
# O              1096
# Eth-Benzene       0
# MP-Xylene         0
# AT                0
# RH                0
# WS                0
# WD                0
# RF                0
# TOT-RF            0
# SR                0
# BP                0
# VWS               0
# dtype: int64

# %%
kolkata.to_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\Kolkata_combined_refined.csv", index=True)

# %%
Beng22 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\BTMLayoutBengaluru2022.csv", index_col="Timestamp", parse_dates=True)
Beng23 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\BTMLayoutBengaluru2023.csv", index_col="Timestamp", parse_dates=True)
Beng24 = pd.read_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\BTMLayoutBengaluru2024.csv", index_col="Timestamp", parse_dates=True)

# %%
bengaluru= pd.concat([Beng22, Beng23, Beng24])
bengaluru
# Out:
#             PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# Timestamp
# 2022-01-01          13.50         28.36       18.91        16.08      33.00
# 2022-01-02          12.67         27.15       18.92        16.08      33.00
# 2022-01-03            NaN           NaN         NaN          NaN        NaN
# 2022-01-04            NaN           NaN         NaN          NaN        NaN
# 2022-01-05            NaN           NaN         NaN          NaN        NaN
# ...                   ...           ...         ...          ...        ...
# 2024-12-27          23.97         44.23        8.35        36.76      45.11
# 2024-12-28          28.65         53.01        8.12        36.06      44.18
# 2024-12-29          29.46         58.98        8.36        37.16      45.52
# 2024-12-30          28.08         55.98        7.75        34.75      42.50
# 2024-12-31          33.41         56.89        8.26        37.05      45.31
#
# ...

# %%
bengaluru.shape
# Out:
# (1096, 24)

# %%
bengaluru.size
# Out:
# 26304

# %%
bengaluru.columns
# Out:
# Index(['PM2.5 (µg/m³)', 'PM10 (µg/m³)', 'NO (µg/m³)', 'NO2 (µg/m³)',
#        'NOx (ppb)', 'NH3 (µg/m³)', 'SO2 (µg/m³)', 'CO (mg/m³)',
#        'Ozone (µg/m³)', 'Benzene (µg/m³)', 'Toluene (µg/m³)', 'Xylene (µg/m³)',
#        'O Xylene (µg/m³)', 'Eth-Benzene (µg/m³)', 'MP-Xylene (µg/m³)',
#        'AT (°C)', 'RH (%)', 'WS (m/s)', 'WD (deg)', 'RF (mm)', 'TOT-RF (mm)',
#        'SR (W/mt2)', 'BP (mmHg)', 'VWS (m/s)'],
#       dtype='str')

# %%
bengaluru.index.duplicated().sum()
# Out:
# np.int64(0)

# %%
bengaluru.info()
# Out:
# <class 'pandas.DataFrame'>
# DatetimeIndex: 1096 entries, 2022-01-01 to 2024-12-31
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PM2.5 (µg/m³)        1019 non-null   float64
#  1   PM10 (µg/m³)         1020 non-null   float64
#  2   NO (µg/m³)           1023 non-null   float64
#  3   NO2 (µg/m³)          1023 non-null   float64
#  4   NOx (ppb)            1024 non-null   float64
#  5   NH3 (µg/m³)          1024 non-null   float64
#  6   SO2 (µg/m³)          1040 non-null   float64
#  7   CO (mg/m³)           1036 non-null   float64
#  8   Ozone (µg/m³)        1041 non-null   float64
#  9   Benzene (µg/m³)      1041 non-null   float64
#  10  Toluene (µg/m³)      1041 non-null   float64
#  11  Xylene (µg/m³)       0 non-null      float64
#  12  O Xylene (µg/m³)     0 non-null      float64
#  13  Eth-Benzene (µg/m³)  1038 non-null   float64
#  14  MP-Xylene (µg/m³)    1038 non-null   float64
# ...

# %%
bengaluru= bengaluru.sort_index()
bengaluru
# Out:
#             PM2.5 (µg/m³)  PM10 (µg/m³)  NO (µg/m³)  NO2 (µg/m³)  NOx (ppb)  \
# Timestamp
# 2022-01-01          13.50         28.36       18.91        16.08      33.00
# 2022-01-02          12.67         27.15       18.92        16.08      33.00
# 2022-01-03            NaN           NaN         NaN          NaN        NaN
# 2022-01-04            NaN           NaN         NaN          NaN        NaN
# 2022-01-05            NaN           NaN         NaN          NaN        NaN
# ...                   ...           ...         ...          ...        ...
# 2024-12-27          23.97         44.23        8.35        36.76      45.11
# 2024-12-28          28.65         53.01        8.12        36.06      44.18
# 2024-12-29          29.46         58.98        8.36        37.16      45.52
# 2024-12-30          28.08         55.98        7.75        34.75      42.50
# 2024-12-31          33.41         56.89        8.26        37.05      45.31
#
# ...

# %%
bengaluru.to_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\Bengaluru_combined.csv", index=True)

# %%
bengaluru.isnull().sum()
# Out:
# PM2.5 (µg/m³)            77
# PM10 (µg/m³)             76
# NO (µg/m³)               73
# NO2 (µg/m³)              73
# NOx (ppb)                72
# NH3 (µg/m³)              72
# SO2 (µg/m³)              56
# CO (mg/m³)               60
# Ozone (µg/m³)            55
# Benzene (µg/m³)          55
# Toluene (µg/m³)          55
# Xylene (µg/m³)         1096
# O Xylene (µg/m³)       1096
# Eth-Benzene (µg/m³)      58
# MP-Xylene (µg/m³)        58
# AT (°C)                1096
# RH (%)                   72
# WS (m/s)                273
# WD (deg)                273
# RF (mm)                1096
# TOT-RF (mm)            1096
# SR (W/mt2)               72
# BP (mmHg)                97
# VWS (m/s)                72
# dtype: int64

# %%
(bengaluru.isnull().sum()/len(bengaluru))*100
# Out:
# PM2.5 (µg/m³)            7.025547
# PM10 (µg/m³)             6.934307
# NO (µg/m³)               6.660584
# NO2 (µg/m³)              6.660584
# NOx (ppb)                6.569343
# NH3 (µg/m³)              6.569343
# SO2 (µg/m³)              5.109489
# CO (mg/m³)               5.474453
# Ozone (µg/m³)            5.018248
# Benzene (µg/m³)          5.018248
# Toluene (µg/m³)          5.018248
# Xylene (µg/m³)         100.000000
# O Xylene (µg/m³)       100.000000
# Eth-Benzene (µg/m³)      5.291971
# MP-Xylene (µg/m³)        5.291971
# AT (°C)                100.000000
# RH (%)                   6.569343
# WS (m/s)                24.908759
# WD (deg)                24.908759
# RF (mm)                100.000000
# TOT-RF (mm)            100.000000
# SR (W/mt2)               6.569343
# BP (mmHg)                8.850365
# VWS (m/s)                6.569343
# dtype: float64

# %%
bengaluru.columns = bengaluru.columns.str.split(" ").str[0]
bengaluru.isnull().sum()
# Out:
# PM2.5            77
# PM10             76
# NO               73
# NO2              73
# NOx              72
# NH3              72
# SO2              56
# CO               60
# Ozone            55
# Benzene          55
# Toluene          55
# Xylene         1096
# O              1096
# Eth-Benzene      58
# MP-Xylene        58
# AT             1096
# RH               72
# WS              273
# WD              273
# RF             1096
# TOT-RF         1096
# SR               72
# BP               97
# VWS              72
# dtype: int64

# %%
bengaluru= bengaluru.ffill()
bengaluru= bengaluru.bfill()

# %%
bengaluru.isnull().sum()
# Out:
# PM2.5             0
# PM10              0
# NO                0
# NO2               0
# NOx               0
# NH3               0
# SO2               0
# CO                0
# Ozone             0
# Benzene           0
# Toluene           0
# Xylene         1096
# O              1096
# Eth-Benzene       0
# MP-Xylene         0
# AT             1096
# RH                0
# WS                0
# WD                0
# RF             1096
# TOT-RF         1096
# SR                0
# BP                0
# VWS               0
# dtype: int64

# %%
bengaluru.to_csv(r"C:\Users\DELL\Downloads\AQI_PROJECT\Bengaluru_combined_refined.csv", index=True)
